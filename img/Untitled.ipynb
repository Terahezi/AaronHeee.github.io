# %%
import numpy as np
import skimage.io as io

# %%
image = io.imread("hzk.jpg")

# %%
import matplotlib.pyplot as plt
% matplotlib inline
plt.figure(figsize=(16, 16))

# %%
plt.imshow(image)
plt.show()

# %%
image[...,0]
# Out:
# array([[206, 206, 206, ...,   1,   1,   1],
#        [206, 206, 206, ...,   1,   1,   1],
#        [206, 206, 206, ...,   1,   1,   1],
#        ...,
#        [ 42,  42,  42, ...,  82,  84,  84],
#        [ 42,  42,  42, ...,  84,  85,  86],
#        [ 42,  42,  42, ...,  84,  85,  86]], dtype=uint8)

# %%
R=image[...,0]>80
G=image[...,1]<80
B=image[...,2]<100

# %%
image[...,0].shape
image_2 = image.copy()
print (R&B).shape
# Out:
# (1080, 1080)

# %%
ftr = R&G&B
image_2[...,0][ftr] = image_2[...,0][ftr] - 50
image_2[...,1][ftr] = image_2[...,0][ftr] + 20
image_2[...,2][ftr] = image_2[...,2][ftr] + 120
print image_2.shape
# Out:
# (1080, 1080, 3)

# %%
image_2[...,0][R&B]
# Out:
# array([103, 106, 106, ..., 134, 126, 132], dtype=uint8)

# %%
R_2=image_2[...,0]>200
G_2=image_2[...,2]<100
B_2=image_2[...,2]<100
np.sum(R_2&B_2)
# Out:
# 0

# %%
plt.figure()
plt.imshow(image_2)
plt.show()

# %%
(image_2 == image).all()
# Out:
# False

# %%
image[800,700,:]
# Out:
# array([71,  2, 23], dtype=uint8)
